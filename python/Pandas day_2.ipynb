# %%
import numpy as np
import pandas as pd

# %%
df =pd.read_csv("/content/sample_data/california_housing_test.csv")

# %%
df.head(1)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0

# %%
data ={
    "Employee":["aditya","sagar","ram","yash"],
    "department":["civil","extc","mech","elec"],
    "salary":[5000,520000,63363,45651]
}

# %%
type(data)
# Out:
# dict

# %%
df=pd.DataFrame(data,index=["Emp01","Emp02","Emp03","Emp04"])

# %%
df
# Out:
#       Employee department  salary
# Emp01   aditya      civil    5000
# Emp02    sagar       extc  520000
# Emp03      ram       mech   63363
# Emp04     yash       elec   45651

# %%
df.loc["Emp03"]  # Loc is a - location of a indexing
# Out:
# Employee        ram
# department     mech
# salary        63363
# Name: Emp03, dtype: object

# %%
df.loc[['Emp03', 'Emp04']]
# Out:
#       Employee department  salary
# Emp03      ram       mech   63363
# Emp04     yash       elec   45651

# %%
df
# Out:
#       Employee department  salary
# Emp01   aditya      civil    5000
# Emp02    sagar       extc  520000
# Emp03      ram       mech   63363
# Emp04     yash       elec   45651

# %%
df.iloc[2]
# Out:
# Employee        ram
# department     mech
# salary        63363
# Name: Emp03, dtype: object

# %%
df
# Out:
#       Employee department  salary
# Emp01   aditya      civil    5000
# Emp02    sagar       extc  520000
# Emp03      ram       mech   63363
# Emp04     yash       elec   45651

# %%
df["Bonus"]=df["salary"]*0.1

# %%
df
# Out:
#       Employee department  salary    Bonus
# Emp01   aditya      civil    5000    500.0
# Emp02    sagar       extc  520000  52000.0
# Emp03      ram       mech   63363   6336.3
# Emp04     yash       elec   45651   4565.1

# %%
new_df =df.where(df["salary"] >40000)

# %%
new_df
# Out:
#       Employee department    salary    Bonus
# Emp01      NaN        NaN       NaN      NaN
# Emp02    sagar       extc  520000.0  52000.0
# Emp03      ram       mech   63363.0   6336.3
# Emp04     yash       elec   45651.0   4565.1

# %%
df["salary_category"]=pd.cut(df["salary"],bins=[40000,50000,60000,700000],labels=["low salary","medium salary","high salary"])

# %% [markdown]
# # pd.cut -
# -it use feature engg. than mean to convert numerical to categorical
# - bins = [0,18,32,60,100]
# - labels=["teen "Adult,senior,]

# %%
df
# Out:
#       Employee department  salary    Bonus salary_category
# Emp01   aditya      civil    5000    500.0             NaN
# Emp02    sagar       extc  520000  52000.0     high salary
# Emp03      ram       mech   63363   6336.3     high salary
# Emp04     yash       elec   45651   4565.1      low salary

# %%
df[["salary","Bonus"]].describe()
# Out:
# <bound method NDFrame.describe of        salary    Bonus
# Emp01    5000    500.0
# Emp02  520000  52000.0
# Emp03   63363   6336.3
# Emp04   45651   4565.1>

# %%
# Out:
#       Employee department  salary    Bonus salary_category
# Emp01   aditya      civil    5000    500.0             NaN
# Emp02    sagar       extc  520000  52000.0     high salary
# Emp03      ram       mech   63363   6336.3     high salary
# Emp04     yash       elec   45651   4565.1      low salary

# %%
df["salary"].mean()
# Out:
# 158503.5

# %%
df["salary"].median()
# Out:
# 54507.0

# %%
df["salary"].mode()
# Out:
# 0      5000
# 1     45651
# 2     63363
# 3    520000
# Name: salary, dtype: int64

# %%
#df.groupby()[]

#always use 1st paranthesis and 2nd swuarebrace
#always use when you need more than one column calculation
#for more thann 2 column pass list in parenthesis
# in sqaure braces  output feature or numerical feature is use

# %%
df.groupby("salary_category")["salary"].mean()
# Out:
# <ipython-input-113-f4d85d18b15a>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby("salary_category")["salary"].mean()
# salary_category
# low salary        45651.0
# medium salary         NaN
# high salary      291681.5
# Name: salary, dtype: float64

# %%
df.groupby(["salary_category","department"])["salary"].mean()
# Out:
# <ipython-input-115-d019a5291917>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(["salary_category","department"])["salary"].mean()
# salary_category  department
# low salary       civil              NaN
#                  elec           45651.0
#                  extc               NaN
#                  mech               NaN
# medium salary    civil              NaN
#                  elec               NaN
#                  extc               NaN
#                  mech               NaN
# high salary      civil              NaN
#                  elec               NaN
#                  extc          520000.0
#                  mech           63363.0
# Name: salary, dtype: float64

# %%
df.groupby(["salary_category","department"])["salary"].mean().unstack()
# Out:
# <ipython-input-116-f8193b218efb>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(["salary_category","department"])["salary"].mean().unstack()
# department       civil     elec      extc     mech
# salary_category
# low salary         NaN  45651.0       NaN      NaN
# medium salary      NaN      NaN       NaN      NaN
# high salary        NaN      NaN  520000.0  63363.0

# %%
df.groupby(["salary_category","department"])["salary"].median()
# Out:
# <ipython-input-117-3b17657b0f06>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(["salary_category","department"])["salary"].median()
# salary_category  department
# low salary       civil              NaN
#                  elec           45651.0
#                  extc               NaN
#                  mech               NaN
# medium salary    civil              NaN
#                  elec               NaN
#                  extc               NaN
#                  mech               NaN
# high salary      civil              NaN
#                  elec               NaN
#                  extc          520000.0
#                  mech           63363.0
# Name: salary, dtype: float64

# %%
df.groupby(["salary_category","department"])["salary"].mean().unstack()
# Out:
# <ipython-input-119-f8193b218efb>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(["salary_category","department"])["salary"].mean().unstack()
# department       civil     elec      extc     mech
# salary_category
# low salary         NaN  45651.0       NaN      NaN
# medium salary      NaN      NaN       NaN      NaN
# high salary        NaN      NaN  520000.0  63363.0

# %%
import seaborn as sns

# %%
df1=sns.load_dataset('titanic')

# %%
df1
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df1.shape
# Out:
# (891, 15)

# %%
df1["sex"].value_counts()
# Out:
# sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df1["survived"].value_counts()
# Out:
# survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
df1.groupby("sex")['survived'].value_counts().unstack()
# Out:
# survived    0    1
# sex
# female     81  233
# male      468  109

# %%
df1["sex"].value_counts(normalize=True)*100
# Out:
# sex
# male      64.758698
# female    35.241302
# Name: proportion, dtype: float64
